# %% [markdown]
# # HTML Notes
# ## Tags
# Tags make up HTMl elements. There are opening tags, that can have attributes, and closing tags. Everything between these tags is the element 'content".
# ### Example

# %% [markdown]
# `<b>This text is bold.</b>`

# %%
# %%html
# <b>This text is bold.</b>
# Out:
# <b>This text is bold.</b>

# %% [markdown]
# ## Attributes
# The opening tag can have attributes, which modify the elements.
# ### Example

# %%
# %%html
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQujbNLO4MezN_OyBGDxJvQjZWSdI9EzCIAx_XKQZiXtA7nXyWPyY_7o4fpZbJw5ZJ0jVQ:https://media.istockphoto.com/id/182690920/photo/cool-guy.jpg%3Fs%3D612x612%26w%3Dis%26k%3D20%26c%3DmB8J78kO8Z6-ansVeKUS7MbwH5W--TdLQyuiTKtSwkk%3D&usqp=CAU">
# Out:
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQujbNLO4MezN_OyBGDxJvQjZWSdI9EzCIAx_XKQZiXtA7nXyWPyY_7o4fpZbJw5ZJ0jVQ:https://media.istockphoto.com/id/182690920/photo/cool-guy.jpg%3Fs%3D612x612%26w%3Dis%26k%3D20%26c%3DmB8J78kO8Z6-ansVeKUS7MbwH5W--TdLQyuiTKtSwkk%3D&usqp=CAU">

# %%
# %%js
# alert("LOOK OUT! IT IS A COOL GUY!");
